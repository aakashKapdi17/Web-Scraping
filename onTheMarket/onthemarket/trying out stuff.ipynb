# %%
with open('postcode-outcodes.csv','r') as fh:
            postcode_data=fh.readlines()
postcodes=[]
for line in postcode_data:
    temp=line.split(",")
    if temp[0].isnumeric():
        postcodes.append(temp[1])
print(postcodes)
# Out:
# ['B34', 'IP10', 'G2', 'GL19', 'L36', 'NE32', 'L12', 'NR28', 'SO21', 'CV3', 'TQ10', 'NE37', 'NW11', 'ST14', 'TN35', 'ME7', 'BB3', 'SE14', 'WA12', 'GL1', 'EC3R', 'BS6', 'NG22', 'DE22', 'BD6', 'HR1', 'BN10', 'PL17', 'SA6', 'CA15', 'WV13', 'DN1', 'PH36', 'LL12', 'OX14', 'CM17', 'TA11', 'WF6', 'G23', 'L13', 'GL16', 'OL11', 'SN26', 'LL47', 'ST17', 'NE99', 'DY11', 'ST18', 'DH99', 'PE35', 'FK17', 'CW12', 'WV2', 'NE16', 'DE4', 'BN25', 'NG33', 'GU1', 'ML9', 'BT80', 'NE65', 'NE7', 'SG8', 'W6', 'DN55', 'FK10', 'M46', 'AB41', 'KA26', 'SN15', 'LE16', 'DH4', 'WD99', 'PH31', 'LL18', 'TF8', 'PA66', 'WD17', 'RG17', 'W1S', 'TA7', 'SY13', 'G53', 'PR8', 'NP11', 'KA12', 'SK10', 'WA8', 'EC2M', 'W13', 'BT12', 'FY4', 'NN4', 'TN27', 'G32', 'DE72', 'SA36', 'BT82', 'WF2', 'LL15', 'SO45', 'CR90', 'YO15', 'LD8', 'WR1', 'RG14', 'OX5', 'PO39', 'AB11', 'TS27', 'HP27', 'BT9', 'SL0', 'NE22', 'LE12', 'TR4', 'TS11', 'IG5', 'RH5', 'TQ1', 'LL67', 'LS26', 'LL32', 'LE21', 'SA14', 'CR7', 'BA6', 'G74', 'IV5', 'PA11', 'RH20', 
# ...
